# %% [markdown]
# <a href="https://colab.research.google.com/github/tatiana687/INTELIGENCIA-ARTIFICIAL-II./blob/main/Resumen_clase_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trabajos de Ciencia de Datos
#
# Los trabajos relacionados con la Ciencia de Datos son cada vez más populares debido al crecimiento de la cantidad de información que generan las empresas y las personas. Estos profesionales se encargan de recopilar, analizar e interpretar datos para obtener información útil y apoyar la toma de decisiones.Ciencia de Datos: los trabajos en esta área son cada vez más populares porque las empresas manejan grandes cantidades de datos y necesitan analizarlos para encontrar información útil, patrones y tendencias.
