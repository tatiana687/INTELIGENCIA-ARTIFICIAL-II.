# %% [markdown]
# <a href="https://colab.research.google.com/github/tatiana687/INTELIGENCIA-ARTIFICIAL-II./blob/main/Resumen_clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Todo empieza con el dato, que es el inicio de todo y donde se recoge y se limpia la información, ya sean números, textos, fotos, videos o audios. Después viene la parte de ahora, que es analizar esos datos ya limpios para crear reportes y gráficas y así entender qué está pasando en el negocio y tomar decisiones. Y por último viene la parte del futuro, que es la ciencia de datos, donde ya no solo vemos qué pasó sino que intentamos predecir qué va a pasar usando métodos tradicionales como regresión y agrupamientos, y también inteligencia artificial que aprende con ejemplos, buscando patrones sola o a base de premios.
